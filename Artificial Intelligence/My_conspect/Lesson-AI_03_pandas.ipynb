# %% [markdown]
# # *Series*

# %%
import numpy as np
import pandas as pd

# %%
salary = pd.Series([3, 2, 0, 1])
salary
# Out:
# 0    3
# 1    2
# 2    0
# 3    1
# dtype: int64

# %%
salary[0]
# Out:
# np.int64(3)

# %%
salary[3]
# Out:
# np.int64(1)

# %%
salary = pd.Series([3, 2, 0, 1], ['Mon', 'Tues', 'Wen', 'Th'])
salary
# Out:
# Mon     3
# Tues    2
# Wen     0
# Th      1
# dtype: int64

# %%
salary['Mon']
# Out:
# np.int64(3)

# %%
salary['Wen']
# Out:
# np.int64(0)

# %%
data = {'a': 1, 'b': 2, 'c': 3}
salary = pd.Series(data)
salary
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
a = 8
salary = pd.Series(a, [1, 2, 3])
salary
# Out:
# 1    8
# 2    8
# 3    8
# dtype: int64

# %%
s1 = pd.Series([1, 2, 3], ['a', 'b', 'c'])
s2 = pd.Series([1, 2, 3], ['a', 'b', 'w']) 
s3 = s1 + s2
s3
# Out:
# a    2.0
# b    4.0
# c    NaN
# w    NaN
# dtype: float64

# %%
s1[s1>2]
# Out:
# c    3
# dtype: int64

# %%
s1[:2]
# Out:
# a    1
# b    2
# dtype: int64

# %%
s1 + 2
# Out:
# a    3
# b    4
# c    5
# dtype: int64

# %% [markdown]
# # *Dataframes*

# %%
import pandas as pd
import numpy as np
from numpy.random  import randn

# %%
df = pd.DataFrame(randn(4, 4), ['a', 'b', 'c', 'd'], ['A', 'B', 'C', 'D'])
df
# Out:
#           A         B         C         D
# a  0.256503  0.664462 -1.444432 -0.475513
# b  1.234971 -0.103937  0.410637 -0.382746
# c  0.539986  1.484119 -0.341863 -1.166681
# d  0.859745  0.587589 -0.581911 -0.053804

# %%
df[['A', 'D']]
# Out:
#           A         D
# a  0.045217 -2.340476
# b -0.043841  0.070707
# c -0.230888  0.725242
# d  1.053252 -0.026661

# %%
df['new'] = df['A'] + df['C']
df
# Out:
#           A         B         C         D       new
# a  0.256503  0.664462 -1.444432 -0.475513 -1.187928
# b  1.234971 -0.103937  0.410637 -0.382746  1.645607
# c  0.539986  1.484119 -0.341863 -1.166681  0.198123
# d  0.859745  0.587589 -0.581911 -0.053804  0.277834

# %%
df.drop('a')
# Out:
#           A         B         C         D       new
# b -0.043841 -0.354183  0.951457  0.070707  0.907616
# c -0.230888 -0.861797 -0.291773  0.725242 -0.522662
# d  1.053252 -2.325644 -0.724363 -0.026661  0.328889

# %%
df
# Out:
#           A         B         C         D       new
# a  0.045217  0.590174 -0.397295 -2.340476 -0.352078
# b -0.043841 -0.354183  0.951457  0.070707  0.907616
# c -0.230888 -0.861797 -0.291773  0.725242 -0.522662
# d  1.053252 -2.325644 -0.724363 -0.026661  0.328889

# %%
df.drop('a', inplace=True)
df
# Out:
#           A         B         C         D       new
# b -0.043841 -0.354183  0.951457  0.070707  0.907616
# c -0.230888 -0.861797 -0.291773  0.725242 -0.522662
# d  1.053252 -2.325644 -0.724363 -0.026661  0.328889

# %%
df.drop('new', axis=1, inplace=True)
df
# Out:
#           A         B         C         D
# a  0.256503  0.664462 -1.444432 -0.475513
# b  1.234971 -0.103937  0.410637 -0.382746
# c  0.539986  1.484119 -0.341863 -1.166681
# d  0.859745  0.587589 -0.581911 -0.053804

# %%
df.shape
# Out:
# (4, 4)

# %%
df.loc['c']
# Out:
# A   -0.230888
# B   -0.861797
# C   -0.291773
# D    0.725242
# Name: c, dtype: float64

# %%
df['B']
# Out:
# b   -0.354183
# c   -0.861797
# d   -2.325644
# Name: B, dtype: float64

# %%
df.iloc[0]
# Out:
# A   -0.043841
# B   -0.354183
# C    0.951457
# D    0.070707
# Name: b, dtype: float64

# %%
df
# Out:
#           A         B         C         D
# a  0.256503  0.664462 -1.444432 -0.475513
# b  1.234971 -0.103937  0.410637 -0.382746
# c  0.539986  1.484119 -0.341863 -1.166681
# d  0.859745  0.587589 -0.581911 -0.053804

# %%
df.loc['c', 'B']
# Out:
# np.float64(1.4841193445210226)

# %%
df.loc[['c', 'd'], ['B', 'C']]
# Out:
#           B         C
# c -0.861797 -0.291773
# d -2.325644 -0.724363

# %%
df[df>0]
# Out:
#           A         B         C   D
# a  0.256503  0.664462       NaN NaN
# b  1.234971       NaN  0.410637 NaN
# c  0.539986  1.484119       NaN NaN
# d  0.859745  0.587589       NaN NaN

# %%
df['B']>0
# Out:
# a     True
# b    False
# c     True
# d     True
# Name: B, dtype: bool

# %%
df[df['B']>1]
# Out:
#           A         B         C         D
# c  0.539986  1.484119 -0.341863 -1.166681

# %%
df.reset_index()
# Out:
#   index         A         B         C         D
# 0     b -0.043841 -0.354183  0.951457  0.070707
# 1     c -0.230888 -0.861797 -0.291773  0.725242
# 2     d  1.053252 -2.325644 -0.724363 -0.026661

# %%
df = pd.read_csv('Real_Estate_Sales_2001-2022_GL.csv')
df
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6096\2940241938.py:1: DtypeWarning: Columns (8,9,10,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Real_Estate_Sales_2001-2022_GL.csv')
#          Serial Number  List Year Date Recorded          Town  \
# 0              2020177       2020    04/14/2021       Ansonia
# 1              2020225       2020    05/26/2021       Ansonia
# 2              2020348       2020    09/13/2021       Ansonia
# 3              2020090       2020    12/14/2020       Ansonia
# 4               210288       2021    06/20/2022          Avon
# ...                ...        ...           ...           ...
# 1097624        2200073       2022    10/11/2022      Stamford
# 1097625         220369       2022    09/29/2023  Wethersfield
# 1097626        2200470       2022    01/09/2023      Stamford
# 1097627          22396       2022    09/26/2023  Old Saybrook
# 1097628         220890       2022    05/18/2023   Southington
#
#                                Address  Assessed Value  Sale Amount  \
# 0                        323 BEAVER ST        133000.0     248400.0
# 1                       152 JACKSON ST        110500.0     239900.0
# 2                      230 WAKELEE AVE        150500.0     325000.0
# 3                          57 PLATT ST        127400.0     202500.0
# 4                       12 BYRON DRIVE        179990.0     362500.0
# ...                                ...             ...          ...
# 1097624           193 SADDLE HILL ROAD        483380.0     865000.0
# 1097625                     37 LUCA LN         20650.0     760857.0
# 1097626  1096 EAST MAIN STREET #16-D-1        132900.0     220000.0
# 1097627               115 SHEFFIELD ST       1099400.0    1575000.0
# 1097628              32 SOUTHINGTON AV        135860.0     330000.0
#
#          Sales Ratio Property Type Residential Type             Non Use Code  \
# 0             0.5354   Residential    Single Family                      NaN
# 1             0.4606   Residential     Three Family                      NaN
# 2             0.4630    Commercial              NaN                      NaN
# 3             0.6291   Residential       Two Family                      NaN
# 4             0.4965   Residential            Condo                      NaN
# ...              ...           ...              ...                      ...
# 1097624       0.5588   Residential    Single Family                      NaN
# 1097625       0.0271   Residential    Single Family  07 - Change in Property
# 1097626       0.6040   Residential            Condo                      NaN
# 1097627       0.6980   Residential    Single Family                      NaN
# 1097628       0.4117   Residential    Single Family  07 - Change in Property
#
#                                       Assessor Remarks  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 1097624                                            NaN
# 1097625  NEW CONSTRUCTION - NOT COMPLETE FOR 10/1/2022
# 1097626                                            NaN
# 1097627                                            NaN
# 1097628                                            NaN
#
#                                                OPM remarks  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1097624                                                NaN
# 1097625                                                NaN
# 1097626                                                NaN
# 1097627                                                NaN
# 1097628  TOTAL RENOVATION PER MLS - SEE PREVIOUS SALE #...
#
#                                    Location
# 0                POINT (-73.06822 41.35014)
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4        POINT (-72.879115982 41.773452988)
# ...                                     ...
# 1097624  POINT (-73.577612999 41.148977983)
# 1097625        POINT (-72.663607 41.712487)
# 1097626  POINT (-73.515726977 41.057837988)
# 1097627  POINT (-72.368005967 41.289124997)
# 1097628   POINT (-72.87929502 41.590926988)
#
# [1097629 rows x 14 columns]

# %%
df.head(2)
# Out:
#    Serial Number  List Year Date Recorded     Town         Address  \
# 0        2020177       2020    04/14/2021  Ansonia   323 BEAVER ST
# 1        2020225       2020    05/26/2021  Ansonia  152 JACKSON ST
#
#    Assessed Value  Sale Amount  Sales Ratio Property Type Residential Type  \
# 0        133000.0     248400.0       0.5354   Residential    Single Family
# 1        110500.0     239900.0       0.4606   Residential     Three Family
#
#   Non Use Code Assessor Remarks OPM remarks                    Location
# 0          NaN              NaN         NaN  POINT (-73.06822 41.35014)
# 1          NaN              NaN         NaN                         NaN

# %%
df.tail(2)
# Out:
#          Serial Number  List Year Date Recorded          Town  \
# 1097627          22396       2022    09/26/2023  Old Saybrook
# 1097628         220890       2022    05/18/2023   Southington
#
#                    Address  Assessed Value  Sale Amount  Sales Ratio  \
# 1097627   115 SHEFFIELD ST       1099400.0    1575000.0       0.6980
# 1097628  32 SOUTHINGTON AV        135860.0     330000.0       0.4117
#
#         Property Type Residential Type             Non Use Code  \
# 1097627   Residential    Single Family                      NaN
# 1097628   Residential    Single Family  07 - Change in Property
#
#         Assessor Remarks                                        OPM remarks  \
# 1097627              NaN                                                NaN
# 1097628              NaN  TOTAL RENOVATION PER MLS - SEE PREVIOUS SALE #...
#
#                                    Location
# 1097627  POINT (-72.368005967 41.289124997)
# 1097628   POINT (-72.87929502 41.590926988)

# %%
df.sample(2)
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 493817          60157       2006    01/19/2007  South Windsor
# 137827          10184       2001    05/28/2002       Stafford
#
#                      Address  Assessed Value  Sale Amount  Sales Ratio  \
# 493817          14 MILLER RD        122840.0     219900.0     0.558618
# 137827  89 FURNACE AVE UT S3         36400.0      75000.0     0.485333
#
#         Property Type Residential Type              Non Use Code  \
# 493817  Single Family    Single Family  06 - Portion of Property
# 137827            NaN              NaN                       NaN
#
#        Assessor Remarks OPM remarks                    Location
# 493817              NaN         NaN                         NaN
# 137827              NaN         NaN  POINT (-72.29978 41.96393)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1097629 entries, 0 to 1097628
# Data columns (total 14 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   Serial Number     1097629 non-null  int64
#  1   List Year         1097629 non-null  int64
#  2   Date Recorded     1097627 non-null  object
#  3   Town              1097629 non-null  object
#  4   Address           1097578 non-null  object
#  5   Assessed Value    1097629 non-null  float64
#  6   Sale Amount       1097629 non-null  float64
#  7   Sales Ratio       1097629 non-null  float64
#  8   Property Type     715183 non-null   object
#  9   Residential Type  699240 non-null   object
#  10  Non Use Code      313451 non-null   object
#  11  Assessor Remarks  171228 non-null   object
#  12  OPM remarks       13031 non-null    object
#  13  Location          298111 non-null   object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 117.2+ MB

# %%
df.describe()
# Out:
#        Serial Number     List Year  Assessed Value   Sale Amount   Sales Ratio
# count   1.097629e+06  1.097629e+06    1.097629e+06  1.097629e+06  1.097629e+06
# mean    5.370357e+05  2.011218e+03    2.818016e+05  4.053146e+05  9.603926e+00
# std     7.526074e+06  6.773485e+00    1.657890e+06  5.143492e+06  1.801664e+03
# min     0.000000e+00  2.001000e+03    0.000000e+00  0.000000e+00  0.000000e+00
# 25%     3.071300e+04  2.005000e+03    8.909000e+04  1.450000e+05  4.778667e-01
# 50%     8.070600e+04  2.011000e+03    1.405800e+05  2.330000e+05  6.105663e-01
# 75%     1.703410e+05  2.018000e+03    2.282700e+05  3.750000e+05  7.707200e-01
# max     2.000500e+09  2.022000e+03    8.815100e+08  5.000000e+09  1.226420e+06

# %%
df = pd.DataFrame({
    'Name': [
        'Canada',
        'France',
        'Germany',
        'Italy',
        'Japan',
        'United Kingdom',
        'United States',
    ],
    'Population': [35.467, 63.951, 80.94 , 60.665, 127.061, 64.511, 318.523],
    'GDP': [
        1785387,
        2833687,
        3874437,
        2167744,
        4602367,
        2950039,
        17348075
    ],
    'Surface Area': [
        9984670,
        640679,
        357114,
        301336,
        377930,
        242495,
        9525067
    ],
    'HDI': [
        0.913,
        0.888,
        0.916,
        0.873,
        0.891,
        0.907,
        0.915
    ],
    'Continent': [
        'America',
        'Europe',
        'Europe',
        'Europe',
        'Asia',
        'Europe',
        'America'
    ]
})

# %%
df
# Out:
#              Name  Population       GDP  Surface Area    HDI Continent
# 0          Canada      35.467   1785387       9984670  0.913   America
# 1          France      63.951   2833687        640679  0.888    Europe
# 2         Germany      80.940   3874437        357114  0.916    Europe
# 3           Italy      60.665   2167744        301336  0.873    Europe
# 4           Japan     127.061   4602367        377930  0.891      Asia
# 5  United Kingdom      64.511   2950039        242495  0.907    Europe
# 6   United States     318.523  17348075       9525067  0.915   America

# %%
df.columns
# Out:
# Index(['Name', 'Population', 'GDP', 'Surface Area', 'HDI', 'Continent'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
df.size
# Out:
# 42

# %%
df.shape
# Out:
# (7, 6)

# %%
df.dtypes
# Out:
# Name             object
# Population      float64
# GDP               int64
# Surface Area      int64
# HDI             float64
# Continent        object
# dtype: object

# %% [markdown]
# ## Індексування та відбір

# %%
df
# Out:
#          Serial Number  List Year Date Recorded          Town  \
# 0              2020177       2020    04/14/2021       Ansonia
# 1              2020225       2020    05/26/2021       Ansonia
# 2              2020348       2020    09/13/2021       Ansonia
# 3              2020090       2020    12/14/2020       Ansonia
# 4               210288       2021    06/20/2022          Avon
# ...                ...        ...           ...           ...
# 1097624        2200073       2022    10/11/2022      Stamford
# 1097625         220369       2022    09/29/2023  Wethersfield
# 1097626        2200470       2022    01/09/2023      Stamford
# 1097627          22396       2022    09/26/2023  Old Saybrook
# 1097628         220890       2022    05/18/2023   Southington
#
#                                Address  Assessed Value  Sale Amount  \
# 0                        323 BEAVER ST        133000.0     248400.0
# 1                       152 JACKSON ST        110500.0     239900.0
# 2                      230 WAKELEE AVE        150500.0     325000.0
# 3                          57 PLATT ST        127400.0     202500.0
# 4                       12 BYRON DRIVE        179990.0     362500.0
# ...                                ...             ...          ...
# 1097624           193 SADDLE HILL ROAD        483380.0     865000.0
# 1097625                     37 LUCA LN         20650.0     760857.0
# 1097626  1096 EAST MAIN STREET #16-D-1        132900.0     220000.0
# 1097627               115 SHEFFIELD ST       1099400.0    1575000.0
# 1097628              32 SOUTHINGTON AV        135860.0     330000.0
#
#          Sales Ratio Property Type Residential Type             Non Use Code  \
# 0             0.5354   Residential    Single Family                      NaN
# 1             0.4606   Residential     Three Family                      NaN
# 2             0.4630    Commercial              NaN                      NaN
# 3             0.6291   Residential       Two Family                      NaN
# 4             0.4965   Residential            Condo                      NaN
# ...              ...           ...              ...                      ...
# 1097624       0.5588   Residential    Single Family                      NaN
# 1097625       0.0271   Residential    Single Family  07 - Change in Property
# 1097626       0.6040   Residential            Condo                      NaN
# 1097627       0.6980   Residential    Single Family                      NaN
# 1097628       0.4117   Residential    Single Family  07 - Change in Property
#
#                                       Assessor Remarks  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 1097624                                            NaN
# 1097625  NEW CONSTRUCTION - NOT COMPLETE FOR 10/1/2022
# 1097626                                            NaN
# 1097627                                            NaN
# 1097628                                            NaN
#
#                                                OPM remarks  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1097624                                                NaN
# 1097625                                                NaN
# 1097626                                                NaN
# 1097627                                                NaN
# 1097628  TOTAL RENOVATION PER MLS - SEE PREVIOUS SALE #...
#
#                                    Location
# 0                POINT (-73.06822 41.35014)
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4        POINT (-72.879115982 41.773452988)
# ...                                     ...
# 1097624  POINT (-73.577612999 41.148977983)
# 1097625        POINT (-72.663607 41.712487)
# 1097626  POINT (-73.515726977 41.057837988)
# 1097627  POINT (-72.368005967 41.289124997)
# 1097628   POINT (-72.87929502 41.590926988)
#
# [1097629 rows x 14 columns]

# %%
df['Population']
# Out:
# 0     35.467
# 1     63.951
# 2     80.940
# 3     60.665
# 4    127.061
# 5     64.511
# 6    318.523
# Name: Population, dtype: float64

# %%
df[['Name', 'Population']]
# Out:
#              Name  Population
# 0          Canada      35.467
# 1          France      63.951
# 2         Germany      80.940
# 3           Italy      60.665
# 4           Japan     127.061
# 5  United Kingdom      64.511
# 6   United States     318.523

# %% [markdown]
# Для індексування `DataFrame` як матрицю `numpy` можна використовувати метод iloc

# %%
df.iloc[:, 0]
# Out:
# 0            Canada
# 1            France
# 2           Germany
# 3             Italy
# 4             Japan
# 5    United Kingdom
# 6     United States
# Name: Name, dtype: object

# %% [markdown]
# Якщо потрібно вказувати не індекси, а назви стовпців, то використовуємо метод loc

# %%
df.loc[:, ['Name', 'Population']]
# Out:
#              Name  Population
# 0          Canada      35.467
# 1          France      63.951
# 2         Germany      80.940
# 3           Italy      60.665
# 4           Japan     127.061
# 5  United Kingdom      64.511
# 6   United States     318.523

# %% [markdown]
# ## Умовний вибір (булеві масиви)
#
# Ми бачили умовний вибір, застосований в `numpy`, і він працюватиме таким же чином для `DataFrame`.

# %%
df
# Out:
#              Name  Population       GDP  Surface Area    HDI Continent
# 0          Canada      35.467   1785387       9984670  0.913   America
# 1          France      63.951   2833687        640679  0.888    Europe
# 2         Germany      80.940   3874437        357114  0.916    Europe
# 3           Italy      60.665   2167744        301336  0.873    Europe
# 4           Japan     127.061   4602367        377930  0.891      Asia
# 5  United Kingdom      64.511   2950039        242495  0.907    Europe
# 6   United States     318.523  17348075       9525067  0.915   America

# %%
df['Population'] > 70
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# Name: Population, dtype: bool

# %%
df[df['Population'] > 70]
# Out:
#             Name  Population       GDP  Surface Area    HDI Continent
# 2        Germany      80.940   3874437        357114  0.916    Europe
# 4          Japan     127.061   4602367        377930  0.891      Asia
# 6  United States     318.523  17348075       9525067  0.915   America

# %% [markdown]
# Булева маска дозволяє вибрати потрібні рядки, враховуючи всі стовпчики. Якщо потрібно вибрати лише деякі стовпці, то використовуємо метод `.loc`

# %%
df.loc[df['Population'] > 70, 'Name']
# Out:
# 2          Germany
# 4            Japan
# 6    United States
# Name: Name, dtype: object

# %%
df.loc[df['Population'] > 70, ['Name', 'Population', 'GDP']]
# Out:
#             Name  Population       GDP
# 2        Germany      80.940   3874437
# 4          Japan     127.061   4602367
# 6  United States     318.523  17348075

# %% [markdown]
# ## Видалення

# %%
df.drop(columns=['Population'])
# Out:
#              Name       GDP  Surface Area    HDI Continent
# 0          Canada   1785387       9984670  0.913   America
# 1          France   2833687        640679  0.888    Europe
# 2         Germany   3874437        357114  0.916    Europe
# 3           Italy   2167744        301336  0.873    Europe
# 4           Japan   4602367        377930  0.891      Asia
# 5  United Kingdom   2950039        242495  0.907    Europe
# 6   United States  17348075       9525067  0.915   America

# %%
df.drop(columns=['Population', 'HDI'])
# Out:
#              Name       GDP  Surface Area Continent
# 0          Canada   1785387       9984670   America
# 1          France   2833687        640679    Europe
# 2         Germany   3874437        357114    Europe
# 3           Italy   2167744        301336    Europe
# 4           Japan   4602367        377930      Asia
# 5  United Kingdom   2950039        242495    Europe
# 6   United States  17348075       9525067   America

# %%
df.drop(['Population', 'HDI'], axis=1)
# Out:
#              Name       GDP  Surface Area Continent
# 0          Canada   1785387       9984670   America
# 1          France   2833687        640679    Europe
# 2         Germany   3874437        357114    Europe
# 3           Italy   2167744        301336    Europe
# 4           Japan   4602367        377930      Asia
# 5  United Kingdom   2950039        242495    Europe
# 6   United States  17348075       9525067   America

# %%
df.drop(['Population', 'HDI'], axis='columns')
# Out:
#              Name       GDP  Surface Area Continent
# 0          Canada   1785387       9984670   America
# 1          France   2833687        640679    Europe
# 2         Germany   3874437        357114    Europe
# 3           Italy   2167744        301336    Europe
# 4           Japan   4602367        377930      Asia
# 5  United Kingdom   2950039        242495    Europe
# 6   United States  17348075       9525067   America

# %%
df
# Out:
#              Name  Population       GDP  Surface Area    HDI Continent
# 0          Canada      35.467   1785387       9984670  0.913   America
# 1          France      63.951   2833687        640679  0.888    Europe
# 2         Germany      80.940   3874437        357114  0.916    Europe
# 3           Italy      60.665   2167744        301336  0.873    Europe
# 4           Japan     127.061   4602367        377930  0.891      Asia
# 5  United Kingdom      64.511   2950039        242495  0.907    Europe
# 6   United States     318.523  17348075       9525067  0.915   America

# %% [markdown]
# ## Операції

# %%
df[['Population', 'GDP']]
# Out:
#    Population       GDP
# 0      35.467   1785387
# 1      63.951   2833687
# 2      80.940   3874437
# 3      60.665   2167744
# 4     127.061   4602367
# 5      64.511   2950039
# 6     318.523  17348075

# %%
df['Population'] * 1000
# Out:
# 0     35467.0
# 1     63951.0
# 2     80940.0
# 3     60665.0
# 4    127061.0
# 5     64511.0
# 6    318523.0
# Name: Population, dtype: float64

# %%
df['Population'].sum()
# Out:
# 751.118

# %%
df['GDP'] / df['Population']
# Out:
# 0    6.332232e+07
# 1    1.812171e+08
# 2    3.135969e+08
# 3    1.315062e+08
# 4    5.847814e+08
# 5    1.903100e+08
# 6    5.525761e+09
# dtype: float64

# %% [markdown]
# ## Зміна даних
#
# Це просто та інтуїтивно зрозуміло. Ви можете без проблем додавати стовпці або замінювати значення для стовпців:

# %% [markdown]
# ### Додавання нового стовпця

# %%
df['Language'] = ['English', 'French', 'German', 'Italian', 'Jananese', 'English', 'English']

# %%
df
# Out:
#              Name  Population       GDP  Surface Area    HDI Continent  \
# 0          Canada      35.467   1785387       9984670  0.913   America
# 1          France      63.951   2833687        640679  0.888    Europe
# 2         Germany      80.940   3874437        357114  0.916    Europe
# 3           Italy      60.665   2167744        301336  0.873    Europe
# 4           Japan     127.061   4602367        377930  0.891      Asia
# 5  United Kingdom      64.511   2950039        242495  0.907    Europe
# 6   United States     318.523  17348075       9525067  0.915   America
#
#    Language
# 0   English
# 1    French
# 2    German
# 3   Italian
# 4  Jananese
# 5   English
# 6   English

# %% [markdown]
# ---
# ### Заміна значень у стовпці

# %%
df['Language'] = 'English'

# %%
df
# Out:
#              Name  Population       GDP  Surface Area    HDI Continent  \
# 0          Canada      35.467   1785387       9984670  0.913   America
# 1          France      63.951   2833687        640679  0.888    Europe
# 2         Germany      80.940   3874437        357114  0.916    Europe
# 3           Italy      60.665   2167744        301336  0.873    Europe
# 4           Japan     127.061   4602367        377930  0.891      Asia
# 5  United Kingdom      64.511   2950039        242495  0.907    Europe
# 6   United States     318.523  17348075       9525067  0.915   America
#
#   Language
# 0  English
# 1  English
# 2  English
# 3  English
# 4  English
# 5  English
# 6  English

# %% [markdown]
# ---
# ### Перейменування стовпців

# %%
df.rename(
    columns={
        'HDI': 'Human Development Index',
        'Anual Popcorn Consumption': 'APC'
    })
# Out:
#              Name  Population       GDP  Surface Area  \
# 0          Canada      35.467   1785387       9984670
# 1          France      63.951   2833687        640679
# 2         Germany      80.940   3874437        357114
# 3           Italy      60.665   2167744        301336
# 4           Japan     127.061   4602367        377930
# 5  United Kingdom      64.511   2950039        242495
# 6   United States     318.523  17348075       9525067
#
#    Human Development Index Continent Language
# 0                    0.913   America  English
# 1                    0.888    Europe  English
# 2                    0.916    Europe  English
# 3                    0.873    Europe  English
# 4                    0.891      Asia  English
# 5                    0.907    Europe  English
# 6                    0.915   America  English

# %% [markdown]
# ---
# ### Видалення стовпців

# %%
df.drop(columns='Language', inplace=True)

# %%
df
# Out:
#              Name  Population       GDP  Surface Area    HDI Continent
# 0          Canada      35.467   1785387       9984670  0.913   America
# 1          France      63.951   2833687        640679  0.888    Europe
# 2         Germany      80.940   3874437        357114  0.916    Europe
# 3           Italy      60.665   2167744        301336  0.873    Europe
# 4           Japan     127.061   4602367        377930  0.891      Asia
# 5  United Kingdom      64.511   2950039        242495  0.907    Europe
# 6   United States     318.523  17348075       9525067  0.915   America

# %% [markdown]
# ---
# ### Зміна індексу

# %%
df.set_index('Name')
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Name
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %% [markdown]
# ## Створення стовпців з інших стовпців
#
# Зміна DataFrame часто передбачає поєднання різних стовпців в інші. Наприклад, у нашому аналізі країн ми могли б спробувати обчислити «ВВП на душу населення», що означає просто `GDP / Population`.

# %%
df[['GDP', 'Population']]
# Out:
#    Population       GDP
# 0      35.467   1785387
# 1      63.951   2833687
# 2      80.940   3874437
# 3      60.665   2167744
# 4     127.061   4602367
# 5      64.511   2950039
# 6     318.523  17348075

# %%
df['GDP'] / df['Population']
# Out:
# 0    50339.385908
# 1    44310.284437
# 2    47868.013343
# 3    35733.025633
# 4    36221.712406
# 5    45729.239975
# 6    54464.120330
# dtype: float64

# %% [markdown]
# Результатом цієї операції є ще одна `Series`, яку ви можете додати до оригінального `DataFrame`:

# %%
df['GDP Per Capita'] = df['GDP'] / df['Population']

# %%
df
# Out:
#              Name  Population       GDP  Surface Area    HDI Continent  \
# 0          Canada      35.467   1785387       9984670  0.913   America
# 1          France      63.951   2833687        640679  0.888    Europe
# 2         Germany      80.940   3874437        357114  0.916    Europe
# 3           Italy      60.665   2167744        301336  0.873    Europe
# 4           Japan     127.061   4602367        377930  0.891      Asia
# 5  United Kingdom      64.511   2950039        242495  0.907    Europe
# 6   United States     318.523  17348075       9525067  0.915   America
#
#    GDP Per Capita
# 0    50339.385908
# 1    44310.284437
# 2    47868.013343
# 3    35733.025633
# 4    36221.712406
# 5    45729.239975
# 6    54464.120330

# %%
df['Continent'].isnull()
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# Name: Continent, dtype: bool

# %% [markdown]
# Для видалення всіх рядків, які мають хоча б одне пропущене значення можна використати метод `dropna`. Після цього бажано перевірити кількість рядків, що залишились.

# %%
df.dropna()
# Out:
#             Name  Population       GDP  Surface Area    HDI Continent  \
# 1         France      63.951   2833687      640679.0  0.888    Europe
# 3          Italy      60.665   2167744      301336.0  0.873    Europe
# 4          Japan     127.061   4602367      377930.0  0.891      Asia
# 6  United States     318.523  17348075     9525067.0  0.915   America
#
#    GDP Per Capita
# 1    44310.284437
# 3    35733.025633
# 4    36221.712406
# 6    54464.120330

# %% [markdown]
# Для видалення рядків, які мають пропуск в конкретному стовпці, можна використати логічну маску.

# %%
df[~df['Continent'].isnull()]
# Out:
#              Name  Population       GDP  Surface Area    HDI Continent  \
# 1          France      63.951   2833687      640679.0  0.888    Europe
# 2         Germany      80.940   3874437           NaN  0.916    Europe
# 3           Italy      60.665   2167744      301336.0  0.873    Europe
# 4           Japan     127.061   4602367      377930.0  0.891      Asia
# 5  United Kingdom      64.511   2950039           NaN  0.907    Europe
# 6   United States     318.523  17348075     9525067.0  0.915   America
#
#    GDP Per Capita
# 1    44310.284437
# 2             NaN
# 3    35733.025633
# 4    36221.712406
# 5    45729.239975
# 6    54464.120330
