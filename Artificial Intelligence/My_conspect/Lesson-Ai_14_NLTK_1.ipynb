# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize

nltk.download('punkt')

text = "I love coffee! It is my favorite drink."

word_tokens = word_tokenize(text)
print("Word tokens:", word_tokens)

sentence_tokens = sent_tokenize(text)
print("Sentence tokens:", sentence_tokens)
# Out:
# Word tokens: ['I', 'love', 'coffee', '!', 'It', 'is', 'my', 'favorite', 'drink', '.']
# Sentence tokens: ['I love coffee!', 'It is my favorite drink.']
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()

words = ['running', 'ran', 'cars', 'better']
lemmatized_words = [lemmatizer.lemmatize(word, pos='v') for word in words]  # 'v' для дієслів
print("Lemmatized words:", lemmatized_words)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Lemmatized words: ['run', 'run', 'cars', 'better']

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()
words = ['running', 'ran', 'runs', 'easily', 'fairly']
stemmed_words = [stemmer.stem(word) for word in words]
print("Stemmed words:", stemmed_words)
# Out:
# Stemmed words: ['run', 'ran', 'run', 'easili', 'fairli']

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')

text = "This is an example showing off stop words filtration."
words = word_tokenize(text.lower())

stop_words = set(stopwords.words('english'))

filtered_words = [word for word in words if word not in stop_words]
print("Filtered words:", filtered_words)
# Out:
# Filtered words: ['example', 'showing', 'stop', 'words', 'filtration', '.']
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# !pip install gensim nltk

import nltk
from nltk.tokenize import word_tokenize
from gensim.models import Word2Vec

nltk.download('punkt')

reviews = [
    "Кава дуже смачна, обслуговування на висоті",
    "Чекав замовлення понад годину, дуже розчарований",
    "Місце затишне, напої чудові",
    "Кава холодна і несмачна"
]

tokenized_reviews = [word_tokenize(review.lower()) for review in reviews]
print("Токенізовані відгуки:", tokenized_reviews)

model = Word2Vec(sentences=tokenized_reviews, vector_size=50, window=3, min_count=1, workers=2, sg=1)  

similar_words = model.wv.most_similar("кава", topn=3)
print("\nСлова, схожі на 'кава':")
for word, score in similar_words:
    print(f"{word} → схожість: {score:.2f}")
# Out:
# Requirement already satisfied: gensim in c:\users\user\desktop\jupyter\nlp_env\lib\site-packages (4.3.1)
# Requirement already satisfied: nltk in c:\users\user\desktop\jupyter\nlp_env\lib\site-packages (3.9.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\user\desktop\jupyter\nlp_env\lib\site-packages (from gensim) (1.23.5)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\user\desktop\jupyter\nlp_env\lib\site-packages (from gensim) (1.9.3)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\user\desktop\jupyter\nlp_env\lib\site-packages (from gensim) (7.3.1)
# Requirement already satisfied: click in c:\users\user\desktop\jupyter\nlp_env\lib\site-packages (from nltk) (8.3.0)
# Requirement already satisfied: joblib in c:\users\user\desktop\jupyter\nlp_env\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\user\desktop\jupyter\nlp_env\lib\site-packages (from nltk) (2025.9.18)
# Requirement already satisfied: tqdm in c:\users\user\desktop\jupyter\nlp_env\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: wrapt in c:\users\user\desktop\jupyter\nlp_env\lib\site-packages (from smart-open>=1.8.1->gensim) (1.17.3)
# Requirement already satisfied: colorama in c:\users\user\desktop\jupyter\nlp_env\lib\site-packages (from click->nltk) (0.4.6)
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Токенізовані відгуки: [['кава', 'дуже', 'смачна', ',', 'обслуговування', 'на', 'висоті'], ['чекав', 'замовлення', 'понад', 'годину', ',', 'дуже', 'розчарований'], ['місце', 'затишне', ',', 'напої', 'чудові'], ['кава', 'холодна', 'і', 'несмачна']]
#
# Слова, схожі на 'кава':
# чудові → схожість: 0.23
# понад → схожість: 0.15
# смачна → схожість: 0.12

# %%
# !pip install gensim

from gensim.models import KeyedVectors

glove_file = '\DataSet\glove.6B.50d.txt'
glove_model = KeyedVectors.load_word2vec_format(glove_file, binary=False, no_header=True)

similar_words_glove = glove_model.most_similar("coffee", topn=3)
print("\nСлова, схожі на 'coffee' (GloVe):")
for word, score in similar_words_glove:
    print(f"{word} → схожість: {score:.2f}")
# Out:
# Requirement already satisfied: gensim in c:\users\user\desktop\jupyter\nlp_env\lib\site-packages (4.3.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\user\desktop\jupyter\nlp_env\lib\site-packages (from gensim) (1.23.5)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\user\desktop\jupyter\nlp_env\lib\site-packages (from gensim) (1.9.3)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\user\desktop\jupyter\nlp_env\lib\site-packages (from gensim) (7.3.1)
# Requirement already satisfied: wrapt in c:\users\user\desktop\jupyter\nlp_env\lib\site-packages (from smart-open>=1.8.1->gensim) (1.17.3)
#
# Слова, схожі на 'coffee' (GloVe):
# drink → схожість: 0.82
# drinks → схожість: 0.82
# wine → схожість: 0.81
